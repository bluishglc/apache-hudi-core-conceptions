// %% [markdown]
// # Apache Hudi Core Conceptions (2) - COW + Simple Index

// %% [markdown]
// ## 1. Configuration

// %%
%%configure -f
{
    "conf" : {
        "spark.jars":"hdfs:///tmp/hudi-spark-bundle.jar",            
        "spark.serializer":"org.apache.spark.serializer.KryoSerializer",
        "spark.sql.extensions":"org.apache.spark.sql.hudi.HoodieSparkSessionExtension",
        "spark.sql.catalog.spark_catalog":"org.apache.spark.sql.hudi.catalog.HoodieCatalog"
    }
}
// Out:
// Current session configs: <tt>{'conf': {'spark.jars': 'hdfs:///tmp/hudi-spark-bundle.jar', 'spark.serializer': 'org.apache.spark.serializer.KryoSerializer', 'spark.sql.extensions': 'org.apache.spark.sql.hudi.HoodieSparkSessionExtension', 'spark.sql.catalog.spark_catalog': 'org.apache.spark.sql.hudi.catalog.HoodieCatalog'}, 'proxyUser': 'user_bluishglc', 'kind': 'spark'}</tt><br>
// No active sessions.

// %%
%%sh
# deploy hudi bundle jar
hdfs dfs -copyFromLocal -f /usr/lib/hudi/hudi-spark-bundle.jar /tmp/hudi-spark-bundle.jar
hdfs dfs -ls /tmp/hudi-spark-bundle.jar
# deploy hudi-stat.sh - a utility shell script 
wget https://github.com/bluishglc/hudi-core-conceptions/releases/download/v1.0/hudi-stat.sh -O ~/hudi-stat.sh &>/dev/null
chmod a+x ~/hudi-stat.sh
ls ~/hudi-stat.sh
// Out:
// -rw-r--r--   1 emr-notebook hdfsadmingroup   61421977 2023-03-04 13:30 /tmp/hudi-spark-bundle.jar
// /home/emr-notebook/hudi-stat.sh

// %%
%%html
<style>
table {float:left}
</style>
// Out:
// <style>
// table {float:left}
// </style>

// %% [markdown]
// ## 2. Test Case 1 - Gradually Increasing

// %% [markdown]
// [0MB, 100MB) -> [100MB, 120MB) -> [120MB, )
//
// KEY|VALUE
// :---|:---
// hoodie.index.type|SIMPLE
// hoodie.copyonwrite.record.size.estimate|175

// %% [markdown]
// ### 2.1. Set Variables

// %%
%%sql
set TABLE_NAME=reviews_cow_simple_1
// Out:
// Starting Spark application
// <table>
// <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>109</td><td>application_1677377031637_0154</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://ip-10-0-143-215.ec2.internal:20888/proxy/application_1677377031637_0154/" class="emr-proxy-link j-2CS22PN3RJ0XE application_1677377031637_0154" emr-resource="j-2CS22PN3RJ0XE
// " application-id="application_1677377031637_0154">Link</a></td><td><a target="_blank" href="http://ip-10-0-134-70.ec2.internal:8042/node/containerlogs/container_1677377031637_0154_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// SparkSession available as 'spark'.
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(children=(HTML(value='Type:'), Button(description='Table', layout=Layout(width='70px'), st…
// Output()

// %%
%env TABLE_NAME=reviews_cow_simple_1
// Out:
// env: TABLE_NAME=reviews_cow_simple_1

// %%
%%sql
set TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_1
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(children=(HTML(value='Type:'), Button(description='Table', layout=Layout(width='70px'), st…
// Output()

// %%
%env TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_1
// Out:
// env: TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_1

// %% [markdown]
// ## 2.2 Create Table

// %%
%%sh
echo $(basename $TABLE_PATH)
aws s3 rm $TABLE_PATH --recursive &>/dev/null
rm -rf ~/${TABLE_NAME}
sleep 5
// Out:
// reviews_cow_simple_1

// %%
%%sql
drop table if exists ${TABLE_NAME}
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %%
%%sql
create table if not exists ${TABLE_NAME}(
    review_id string, 
    star_rating int, 
    review_body string, 
    review_date date, 
    year long,
    timestamp long,
    parity int
)
using hudi
location '${TABLE_PATH}'
partitioned by (parity)
options ( 
    type = 'cow',  
    primaryKey = 'review_id', 
    preCombineField = 'timestamp',
    hoodie.index.type = 'SIMPLE',
    hoodie.copyonwrite.record.size.estimate = '175'
);
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %% [markdown]
// ### 2.3. Batch 1 - Insert ( 0 -> 96MB / Partition )

// %%
%%sql
insert into 
    ${TABLE_NAME}
select 
    review_id, 
    star_rating, 
    review_body, 
    review_date, 
    year,
    unix_timestamp(current_timestamp()) as timestamp,
    mod(crc32(review_id), 2) as parity
from
    reviews
where
    year = 2003;
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %%
%%sh
~/hudi-stat.sh $TABLE_PATH timeline commits storage
// Out:
// [ TIMELINE ]
//
// ╔═════╤═══════════════════╤════════╤═══════════╤═════════════╤═════════════╤═════════════╗
// ║ No. │ Instant           │ Action │ State     │ Requested   │ Inflight    │ Completed   ║
// ║     │                   │        │           │ Time        │ Time        │ Time        ║
// ╠═════╪═══════════════════╪════════╪═══════════╪═════════════╪═════════════╪═════════════╣
// ║ 0   │ 20230304133050232 │ commit │ COMPLETED │ 03-04 13:30 │ 03-04 13:31 │ 03-04 13:31 ║
// ╚═════╧═══════════════════╧════════╧═══════════╧═════════════╧═════════════╧═════════════╝
//
// [ COMMITS ]
//
// ╔═══════════════════╤═════════════════════╤═══════════════════╤═════════════════════╤══════════════════════════╤═══════════════════════╤══════════════════════════════╤══════════════╗
// ║ CommitTime        │ Total Bytes Written │ Total Files Added │ Total Files Updated │ Total Partitions Written │ Total Records Written │ Total Update Records Written │ Total Errors ║
// ╠═══════════════════╪═════════════════════╪═══════════════════╪═════════════════════╪══════════════════════════╪═══════════════════════╪══════════════════════════════╪══════════════╣
// ║ 20230304133050232 │ 191.6 MB            │ 2                 │ 0                   │ 2                        │ 1155127               │ 0                            │ 0            ║
// ╚═══════════════════╧═════════════════════╧═══════════════════╧═════════════════════╧══════════════════════════╧═══════════════════════╧══════════════════════════════╧══════════════╝
//
// [ FSVIEW ]
//
// ╔═══════════╤════════════════════════════════════════╤═══════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════╤═════════════════╤═══════════════════════╤═════════════╗
// ║ Partition │ FileId                                 │ Base-Instant      │ Data-File                                                                                                                                       │ Data-File Size │ Num Delta Files │ Total Delta File Size │ Delta Files ║
// ╠═══════════╪════════════════════════════════════════╪═══════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════╪═════════════════╪═══════════════════════╪═════════════╣
// ║ parity=0  │ 94f48835-921d-4e62-8019-391db5728bfb-0 │ 20230304133050232 │ s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_1/parity=0/94f48835-921d-4e62-8019-391db5728bfb-0_0-29-235_20230304133050232.parquet │ 95.7 MB        │ 0               │ 0.0 B                 │ []          ║
// ╟───────────┼────────────────────────────────────────┼───────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────┼─────────────────┼───────────────────────┼─────────────╢
// ║ parity=1  │ edb63c01-3c10-4688-9a11-ca4a62ae60f0-0 │ 20230304133050232 │ s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_1/parity=1/edb63c01-3c10-4688-9a11-ca4a62ae60f0-0_1-29-236_20230304133050232.parquet │ 95.9 MB        │ 0               │ 0.0 B                 │ []          ║
// ╚═══════════╧════════════════════════════════════════╧═══════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════╧═════════════════╧═══════════════════════╧═════════════╝
//
// [ STORAGE ]
//
// /home/emr-notebook/reviews_cow_simple_1
// ├── [ 96M 13:32:13]  parity=0
// │   └── [ 96M 13:31:31]  94f48835-921d-4e62-8019-391db5728bfb-0_0-29-235_20230304133050232.parquet
// └── [ 96M 13:32:13]  parity=1
//     └── [ 96M 13:31:31]  edb63c01-3c10-4688-9a11-ca4a62ae60f0-0_1-29-236_20230304133050232.parquet
//
//  192M used in 2 directories, 2 files

// %% [markdown]
// ### 2.4. Batch 2 - Insert ( 96MB -> 110MB / Partition )

// %%
%%sql
insert into 
    ${TABLE_NAME}
select 
    review_id, 
    star_rating, 
    review_body, 
    review_date, 
    year,
    unix_timestamp(current_timestamp()) as timestamp,
    mod(crc32(review_id), 2) as parity
from
    reviews
where
    year = 1998;

// %%
%%sh
~/hudi-stat.sh $TABLE_PATH timeline commits storage

// %% [markdown]
// ### 2.5. Batch 3 - Insert ( 110MB -> 113.7MB / Partition )

// %%
%%sql
insert into 
    ${TABLE_NAME}
select 
    review_id, 
    star_rating, 
    review_body, 
    review_date, 
    year,
    unix_timestamp(current_timestamp()) as timestamp,
    mod(crc32(review_id), 2) as parity
from
    reviews
where
    year = 1997;
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %%
%%sh
~/hudi-stat.sh $TABLE_PATH timeline commits storage
// Out:
// [ TIMELINE ]
//
// ╔═════╤═══════════════════╤════════╤═══════════╤═════════════╤═════════════╤═════════════╗
// ║ No. │ Instant           │ Action │ State     │ Requested   │ Inflight    │ Completed   ║
// ║     │                   │        │           │ Time        │ Time        │ Time        ║
// ╠═════╪═══════════════════╪════════╪═══════════╪═════════════╪═════════════╪═════════════╣
// ║ 0   │ 20230304084117098 │ commit │ COMPLETED │ 03-04 08:41 │ 03-04 08:41 │ 03-04 08:42 ║
// ╟─────┼───────────────────┼────────┼───────────┼─────────────┼─────────────┼─────────────╢
// ║ 1   │ 20230304084231301 │ commit │ COMPLETED │ 03-04 08:42 │ 03-04 08:42 │ 03-04 08:43 ║
// ╟─────┼───────────────────┼────────┼───────────┼─────────────┼─────────────┼─────────────╢
// ║ 2   │ 20230304084333433 │ commit │ COMPLETED │ 03-04 08:43 │ 03-04 08:43 │ 03-04 08:43 ║
// ╚═════╧═══════════════════╧════════╧═══════════╧═════════════╧═════════════╧═════════════╝
//
// [ COMMITS ]
//
// ╔═══════════════════╤═════════════════════╤═══════════════════╤═════════════════════╤══════════════════════════╤═══════════════════════╤══════════════════════════════╤══════════════╗
// ║ CommitTime        │ Total Bytes Written │ Total Files Added │ Total Files Updated │ Total Partitions Written │ Total Records Written │ Total Update Records Written │ Total Errors ║
// ╠═══════════════════╪═════════════════════╪═══════════════════╪═════════════════════╪══════════════════════════╪═══════════════════════╪══════════════════════════════╪══════════════╣
// ║ 20230304084333433 │ 7.4 MB              │ 2                 │ 0                   │ 2                        │ 39868                 │ 0                            │ 0            ║
// ╟───────────────────┼─────────────────────┼───────────────────┼─────────────────────┼──────────────────────────┼───────────────────────┼──────────────────────────────┼──────────────╢
// ║ 20230304084231301 │ 220.9 MB            │ 0                 │ 2                   │ 2                        │ 1333111               │ 0                            │ 0            ║
// ╟───────────────────┼─────────────────────┼───────────────────┼─────────────────────┼──────────────────────────┼───────────────────────┼──────────────────────────────┼──────────────╢
// ║ 20230304084117098 │ 191.6 MB            │ 2                 │ 0                   │ 2                        │ 1155127               │ 0                            │ 0            ║
// ╚═══════════════════╧═════════════════════╧═══════════════════╧═════════════════════╧══════════════════════════╧═══════════════════════╧══════════════════════════════╧══════════════╝
//
// [ STORAGE ]
//
// /home/emr-notebook/reviews_cow_simple_1
// ├── [210M 08:44:12]  parity=0
// │   ├── [3.7M 08:43:43]  018f9072-2104-4ef6-9ab6-26ac28090ea7-0_0-114-893_20230304084333433.parquet
// │   ├── [ 96M 08:41:57]  2241459d-1ba7-47af-9f83-fa883b4132c4-0_0-29-235_20230304084117098.parquet
// │   └── [110M 08:43:03]  2241459d-1ba7-47af-9f83-fa883b4132c4-0_0-70-540_20230304084231301.parquet
// └── [210M 08:44:11]  parity=1
//     ├── [3.7M 08:43:43]  5738ba3d-c44b-4deb-bf82-1aac33423a2a-0_1-114-894_20230304084333433.parquet
//     ├── [ 96M 08:41:57]  715ad43a-2f75-44e0-9748-a53b725fb9a3-0_1-29-236_20230304084117098.parquet
//     └── [111M 08:43:03]  715ad43a-2f75-44e0-9748-a53b725fb9a3-0_1-70-541_20230304084231301.parquet
//
//  420M used in 2 directories, 6 files

// %% [markdown]
// ## 3. Test Case 2 - Sharply Increasing

// %% [markdown]
// [0MB, 100MB) -> [100MB, 120MB) -> [120MB, )
//
// KEY|VALUE
// :---|:---
// hoodie.index.type|SIMPLE
// hoodie.copyonwrite.record.size.estimate|175

// %% [markdown]
// ### 3.1. Set Variables

// %%
%%sql
set TABLE_NAME=reviews_cow_simple_2
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(children=(HTML(value='Type:'), Button(description='Table', layout=Layout(width='70px'), st…
// Output()

// %%
%env TABLE_NAME=reviews_cow_simple_2
// Out:
// env: TABLE_NAME=reviews_cow_simple_2

// %%
%%sql
set TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_2
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(children=(HTML(value='Type:'), Button(description='Table', layout=Layout(width='70px'), st…
// Output()

// %%
%env TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_2
// Out:
// env: TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_2

// %% [markdown]
// ## 3.2 Create Table

// %%
%%sh
echo $(basename $TABLE_PATH)
aws s3 rm $TABLE_PATH --recursive &>/dev/null
rm -rf ~/${TABLE_NAME}
sleep 5
// Out:
// reviews_cow_simple_2

// %%
%%sql
drop table if exists ${TABLE_NAME}
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %%
%%sql
create table if not exists ${TABLE_NAME}(
    review_id string, 
    star_rating int, 
    review_body string, 
    review_date date, 
    year long,
    timestamp long,
    parity int
)
using hudi
location '${TABLE_PATH}'
partitioned by (parity)
options ( 
    type = 'cow',  
    primaryKey = 'review_id', 
    preCombineField = 'timestamp',
    hoodie.index.type = 'SIMPLE',
    hoodie.copyonwrite.record.size.estimate = '175'
);
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %% [markdown]
// ### 3.3. Batch 1 - Insert ( 0 -> 341MB / Partition )

// %%
%%sql
insert into 
    ${TABLE_NAME}
select 
    review_id, 
    star_rating, 
    review_body, 
    review_date, 
    year,
    unix_timestamp(current_timestamp()) as timestamp,
    mod(crc32(review_id), 2) as parity
from
    reviews
where
    year = 2010;
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %%
%%sh
~/hudi-stat.sh $TABLE_PATH timeline commits storage
// Out:
// [ TIMELINE ]
//
// ╔═════╤═══════════════════╤════════╤═══════════╤═════════════╤═════════════╤═════════════╗
// ║ No. │ Instant           │ Action │ State     │ Requested   │ Inflight    │ Completed   ║
// ║     │                   │        │           │ Time        │ Time        │ Time        ║
// ╠═════╪═══════════════════╪════════╪═══════════╪═════════════╪═════════════╪═════════════╣
// ║ 0   │ 20230304084423631 │ commit │ COMPLETED │ 03-04 08:44 │ 03-04 08:44 │ 03-04 08:45 ║
// ╚═════╧═══════════════════╧════════╧═══════════╧═════════════╧═════════════╧═════════════╝
//
// [ COMMITS ]
//
// ╔═══════════════════╤═════════════════════╤═══════════════════╤═════════════════════╤══════════════════════════╤═══════════════════════╤══════════════════════════════╤══════════════╗
// ║ CommitTime        │ Total Bytes Written │ Total Files Added │ Total Files Updated │ Total Partitions Written │ Total Records Written │ Total Update Records Written │ Total Errors ║
// ╠═══════════════════╪═════════════════════╪═══════════════════╪═════════════════════╪══════════════════════════╪═══════════════════════╪══════════════════════════════╪══════════════╣
// ║ 20230304084423631 │ 682.5 MB            │ 6                 │ 0                   │ 2                        │ 4119699               │ 0                            │ 0            ║
// ╚═══════════════════╧═════════════════════╧═══════════════════╧═════════════════════╧══════════════════════════╧═══════════════════════╧══════════════════════════════╧══════════════╝
//
// [ STORAGE ]
//
// /home/emr-notebook/reviews_cow_simple_2
// ├── [341M 08:45:45]  parity=0
// │   ├── [119M 08:45:13]  553b470d-4040-491e-976e-8c94219ded40-0_1-173-1166_20230304084423631.parquet
// │   ├── [119M 08:45:13]  9a0923b7-1117-4194-8271-b58b05c9c23f-0_0-173-1165_20230304084423631.parquet
// │   └── [103M 08:45:10]  c156c0a6-dae1-4ce6-81c3-f836eeeb51ef-0_2-173-1167_20230304084423631.parquet
// └── [341M 08:45:45]  parity=1
//     ├── [103M 08:45:10]  6f5dcc68-02c4-4a83-812b-3bc1b3d2910b-0_5-173-1170_20230304084423631.parquet
//     ├── [119M 08:45:13]  835270e8-69b4-4654-834c-c0d6aee61af8-0_4-173-1169_20230304084423631.parquet
//     └── [119M 08:45:13]  c20de252-17cb-4ad3-9ea0-9d5cfba0d24a-0_3-173-1168_20230304084423631.parquet
//
//  683M used in 2 directories, 6 files

// %% [markdown]
// ## 4. Test Case 3 -  Default Settings

// %% [markdown]
// ### 4.1. Set Variables

// %%
%%sql
set TABLE_NAME=reviews_cow_simple_3
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(children=(HTML(value='Type:'), Button(description='Table', layout=Layout(width='70px'), st…
// Output()

// %%
%env TABLE_NAME=reviews_cow_simple_3
// Out:
// env: TABLE_NAME=reviews_cow_simple_3

// %%
%%sql
set TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_3
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(children=(HTML(value='Type:'), Button(description='Table', layout=Layout(width='70px'), st…
// Output()

// %%
%env TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_3
// Out:
// env: TABLE_PATH=s3://glc-examples/hudi-core-conceptions/reviews_cow_simple_3

// %% [markdown]
// ## 4.2 Create Table

// %%
%%sh
echo $(basename $TABLE_PATH)
aws s3 rm $TABLE_PATH --recursive &>/dev/null
rm -rf ~/${TABLE_NAME}
sleep 5
// Out:
// reviews_cow_simple_3

// %%
%%sql
drop table if exists ${TABLE_NAME}
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %%
%%sql
create table if not exists ${TABLE_NAME}(
    review_id string, 
    star_rating int, 
    review_body string, 
    review_date date, 
    year long,
    timestamp long,
    parity int
)
using hudi
location '${TABLE_PATH}'
partitioned by (parity)
options ( 
    type = 'cow',  
    primaryKey = 'review_id', 
    preCombineField = 'timestamp'
    -- hoodie.index.type = 'SIMPLE',
    -- hoodie.copyonwrite.record.size.estimate = '175'
);
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %% [markdown]
// ### 4.3. Batch 1 - Insert ( 0 -> 96MB / Partition )

// %%
%%sql
insert into 
    ${TABLE_NAME}
select 
    review_id, 
    star_rating, 
    review_body, 
    review_date, 
    year,
    unix_timestamp(current_timestamp()) as timestamp,
    mod(crc32(review_id), 2) as parity
from
    reviews
where
    year = 2003;
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %%
%%sh
~/hudi-stat.sh $TABLE_PATH timeline commits storage
// Out:
// [ TIMELINE ]
//
// ╔═════╤═══════════════════╤════════╤═══════════╤═════════════╤═════════════╤═════════════╗
// ║ No. │ Instant           │ Action │ State     │ Requested   │ Inflight    │ Completed   ║
// ║     │                   │        │           │ Time        │ Time        │ Time        ║
// ╠═════╪═══════════════════╪════════╪═══════════╪═════════════╪═════════════╪═════════════╣
// ║ 0   │ 20230304084557586 │ commit │ COMPLETED │ 03-04 08:45 │ 03-04 08:46 │ 03-04 08:46 ║
// ╚═════╧═══════════════════╧════════╧═══════════╧═════════════╧═════════════╧═════════════╝
//
// [ COMMITS ]
//
// ╔═══════════════════╤═════════════════════╤═══════════════════╤═════════════════════╤══════════════════════════╤═══════════════════════╤══════════════════════════════╤══════════════╗
// ║ CommitTime        │ Total Bytes Written │ Total Files Added │ Total Files Updated │ Total Partitions Written │ Total Records Written │ Total Update Records Written │ Total Errors ║
// ╠═══════════════════╪═════════════════════╪═══════════════════╪═════════════════════╪══════════════════════════╪═══════════════════════╪══════════════════════════════╪══════════════╣
// ║ 20230304084557586 │ 198.3 MB            │ 10                │ 0                   │ 2                        │ 1155127               │ 0                            │ 0            ║
// ╚═══════════════════╧═════════════════════╧═══════════════════╧═════════════════════╧══════════════════════════╧═══════════════════════╧══════════════════════════════╧══════════════╝
//
// [ STORAGE ]
//
// /home/emr-notebook/reviews_cow_simple_3
// ├── [ 99M 08:46:44]  parity=0
// │   ├── [ 21M 08:46:16]  1152b241-9796-416e-935b-46e6036e91cb-0_0-232-1497_20230304084557586.parquet
// │   ├── [ 15M 08:46:15]  3b0c48ce-34e4-45f7-850a-df0e6ded3f6e-0_4-232-1501_20230304084557586.parquet
// │   ├── [ 21M 08:46:16]  7da2f0a0-889c-4daa-b4f8-03431044e417-0_3-232-1500_20230304084557586.parquet
// │   ├── [ 21M 08:46:17]  b65d7402-d32c-4c25-a899-a8be7bddd159-0_2-232-1499_20230304084557586.parquet
// │   └── [ 21M 08:46:16]  e59b3d4e-c835-4df0-80c6-f987f501b838-0_1-232-1498_20230304084557586.parquet
// └── [ 99M 08:46:44]  parity=1
//     ├── [ 21M 08:46:16]  483db42e-127f-4726-87cb-3627c42e56f6-0_7-232-1504_20230304084557586.parquet
//     ├── [ 21M 08:46:16]  802f93d0-d86c-4e17-9044-1ce7449f6115-0_6-232-1503_20230304084557586.parquet
//     ├── [ 21M 08:46:16]  82094f0d-5c46-4f61-a529-519d527a03f6-0_8-232-1505_20230304084557586.parquet
//     ├── [ 21M 08:46:16]  ae4185ac-4c8a-4821-a14d-227197520abd-0_5-232-1502_20230304084557586.parquet
//     └── [ 15M 08:46:15]  b0157a0a-0ab4-4a60-9561-9c82d0c1e606-0_9-232-1506_20230304084557586.parquet
//
//  198M used in 2 directories, 10 files

// %% [markdown]
// ### 4.3. Batch 2 - Insert ( 96MB -> 417MB / Partition )

// %%
%%sql
insert into 
    ${TABLE_NAME}
select 
    review_id, 
    star_rating, 
    review_body, 
    review_date, 
    year,
    unix_timestamp(current_timestamp()) as timestamp,
    mod(crc32(review_id), 2) as parity
from
    reviews
where
    year = 2010;
// Out:
// FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
// <style>.jp-OutputArea-child .jupyter-widgets.jp-OutputArea-output { overflow: auto; }</style>
// VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
// Output()

// %%
%%sh
~/hudi-stat.sh $TABLE_PATH timeline commits storage
// Out:
// [ TIMELINE ]
//
// ╔═════╤═══════════════════╤════════╤═══════════╤═════════════╤═════════════╤═════════════╗
// ║ No. │ Instant           │ Action │ State     │ Requested   │ Inflight    │ Completed   ║
// ║     │                   │        │           │ Time        │ Time        │ Time        ║
// ╠═════╪═══════════════════╪════════╪═══════════╪═════════════╪═════════════╪═════════════╣
// ║ 0   │ 20230304084557586 │ commit │ COMPLETED │ 03-04 08:45 │ 03-04 08:46 │ 03-04 08:46 ║
// ╟─────┼───────────────────┼────────┼───────────┼─────────────┼─────────────┼─────────────╢
// ║ 1   │ 20230304084646418 │ commit │ COMPLETED │ 03-04 08:46 │ 03-04 08:47 │ 03-04 08:48 ║
// ╚═════╧═══════════════════╧════════╧═══════════╧═════════════╧═════════════╧═════════════╝
//
// [ COMMITS ]
//
// ╔═══════════════════╤═════════════════════╤═══════════════════╤═════════════════════╤══════════════════════════╤═══════════════════════╤══════════════════════════════╤══════════════╗
// ║ CommitTime        │ Total Bytes Written │ Total Files Added │ Total Files Updated │ Total Partitions Written │ Total Records Written │ Total Update Records Written │ Total Errors ║
// ╠═══════════════════╪═════════════════════╪═══════════════════╪═════════════════════╪══════════════════════════╪═══════════════════════╪══════════════════════════════╪══════════════╣
// ║ 20230304084646418 │ 834.0 MB            │ 0                 │ 8                   │ 2                        │ 5028224               │ 0                            │ 0            ║
// ╟───────────────────┼─────────────────────┼───────────────────┼─────────────────────┼──────────────────────────┼───────────────────────┼──────────────────────────────┼──────────────╢
// ║ 20230304084557586 │ 198.3 MB            │ 10                │ 0                   │ 2                        │ 1155127               │ 0                            │ 0            ║
// ╚═══════════════════╧═════════════════════╧═══════════════════╧═════════════════════╧══════════════════════════╧═══════════════════════╧══════════════════════════════╧══════════════╝
//
// [ STORAGE ]
//
// /home/emr-notebook/reviews_cow_simple_3
// ├── [516M 08:48:44]  parity=0
// │   ├── [ 21M 08:46:16]  1152b241-9796-416e-935b-46e6036e91cb-0_0-232-1497_20230304084557586.parquet
// │   ├── [116M 08:48:10]  3b0c48ce-34e4-45f7-850a-df0e6ded3f6e-0_0-280-1880_20230304084646418.parquet
// │   ├── [ 15M 08:46:15]  3b0c48ce-34e4-45f7-850a-df0e6ded3f6e-0_4-232-1501_20230304084557586.parquet
// │   ├── [ 21M 08:46:16]  7da2f0a0-889c-4daa-b4f8-03431044e417-0_3-232-1500_20230304084557586.parquet
// │   ├── [ 69M 08:48:02]  7da2f0a0-889c-4daa-b4f8-03431044e417-0_3-280-1883_20230304084646418.parquet
// │   ├── [116M 08:48:11]  b65d7402-d32c-4c25-a899-a8be7bddd159-0_1-280-1881_20230304084646418.parquet
// │   ├── [ 21M 08:46:17]  b65d7402-d32c-4c25-a899-a8be7bddd159-0_2-232-1499_20230304084557586.parquet
// │   ├── [ 21M 08:46:16]  e59b3d4e-c835-4df0-80c6-f987f501b838-0_1-232-1498_20230304084557586.parquet
// │   └── [116M 08:48:10]  e59b3d4e-c835-4df0-80c6-f987f501b838-0_2-280-1882_20230304084646418.parquet
// └── [516M 08:48:45]  parity=1
//     ├── [ 21M 08:46:16]  483db42e-127f-4726-87cb-3627c42e56f6-0_7-232-1504_20230304084557586.parquet
//     ├── [ 21M 08:46:16]  802f93d0-d86c-4e17-9044-1ce7449f6115-0_6-232-1503_20230304084557586.parquet
//     ├── [ 70M 08:48:02]  802f93d0-d86c-4e17-9044-1ce7449f6115-0_7-280-1887_20230304084646418.parquet
//     ├── [116M 08:48:10]  82094f0d-5c46-4f61-a529-519d527a03f6-0_5-280-1885_20230304084646418.parquet
//     ├── [ 21M 08:46:16]  82094f0d-5c46-4f61-a529-519d527a03f6-0_8-232-1505_20230304084557586.parquet
//     ├── [ 21M 08:46:16]  ae4185ac-4c8a-4821-a14d-227197520abd-0_5-232-1502_20230304084557586.parquet
//     ├── [116M 08:48:10]  ae4185ac-4c8a-4821-a14d-227197520abd-0_6-280-1886_20230304084646418.parquet
//     ├── [116M 08:48:10]  b0157a0a-0ab4-4a60-9561-9c82d0c1e606-0_4-280-1884_20230304084646418.parquet
//     └── [ 15M 08:46:15]  b0157a0a-0ab4-4a60-9561-9c82d0c1e606-0_9-232-1506_20230304084557586.parquet
//
//  1.0G used in 2 directories, 18 files
